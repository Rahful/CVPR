# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

import random
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(f"Shape of x_train: {x_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print()
print(f"Shape of x_test: {x_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of x_train: (60000, 28, 28)
# Shape of y_train: (60000,)
#
# Shape of x_test: (10000, 28, 28)
# Shape of y_test: (10000,)

# %%
i = 0
plt.figure(figsize=(10,8))
for i in range(80):
    plt.subplot(10,8, i+1)
    plt.imshow(x_train[i], cmap=plt.cm.gray_r)
        
    plt.xticks([])
    plt.yticks([])
    plt.xlabel(y_train[i])
plt.tight_layout()
plt.show()

# %%
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = keras.Sequential([
    keras.Input(shape=(28,28,1)),
    
    layers.Conv2D(filters=32, kernel_size=(5,5), activation='relu'), # input->(32,32) output->(28,28)
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    
    layers.Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                102464
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# ...

# %%
model.compile(
    optimizer='adam', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
h = model.fit(x=x_train, y=y_train, epochs=5, validation_split=0.3, batch_size=64)
# Out:
# Epoch 1/5
# 657/657 [==============================] - 19s 24ms/step - loss: 0.4570 - accuracy: 0.8578 - val_loss: 0.0827 - val_accuracy: 0.9742
# Epoch 2/5
# 657/657 [==============================] - 13s 20ms/step - loss: 0.0678 - accuracy: 0.9795 - val_loss: 0.0602 - val_accuracy: 0.9816
# Epoch 3/5
# 657/657 [==============================] - 13s 20ms/step - loss: 0.0384 - accuracy: 0.9881 - val_loss: 0.0499 - val_accuracy: 0.9849
# Epoch 4/5
# 657/657 [==============================] - 14s 21ms/step - loss: 0.0320 - accuracy: 0.9902 - val_loss: 0.0557 - val_accuracy: 0.9833
# Epoch 5/5
# 657/657 [==============================] - 13s 20ms/step - loss: 0.0227 - accuracy: 0.9928 - val_loss: 0.0420 - val_accuracy: 0.9884

# %%
model.compile(
   optimizer='SGD', 
   loss='sparse_categorical_crossentropy', 
   metrics=['accuracy']
 )

# %%
h = model.fit(x=x_train, y=y_train, epochs=5, validation_split=0.3, batch_size=64)
# Out:
# Epoch 1/5
# 657/657 [==============================] - 13s 19ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.0373 - val_accuracy: 0.9900
# Epoch 2/5
# 657/657 [==============================] - 12s 19ms/step - loss: 0.0089 - accuracy: 0.9977 - val_loss: 0.0372 - val_accuracy: 0.9903
# Epoch 3/5
# 657/657 [==============================] - 12s 19ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.0373 - val_accuracy: 0.9904
# Epoch 4/5
# 657/657 [==============================] - 13s 19ms/step - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.0378 - val_accuracy: 0.9903
# Epoch 5/5
# 657/657 [==============================] - 13s 19ms/step - loss: 0.0082 - accuracy: 0.9980 - val_loss: 0.0375 - val_accuracy: 0.9905

# %%
model.compile(
   optimizer='RMSProp', 
   loss='sparse_categorical_crossentropy', 
   metrics=['accuracy']
 )

# %%
h = model.fit(x=x_train, y=y_train, epochs=5, validation_split=0.3, batch_size=64)
# Out:
# Epoch 1/5
# 657/657 [==============================] - 16s 24ms/step - loss: 0.0196 - accuracy: 0.9934 - val_loss: 0.0449 - val_accuracy: 0.9876
# Epoch 2/5
# 657/657 [==============================] - 15s 23ms/step - loss: 0.0151 - accuracy: 0.9951 - val_loss: 0.0409 - val_accuracy: 0.9902
# Epoch 3/5
# 657/657 [==============================] - 15s 23ms/step - loss: 0.0134 - accuracy: 0.9953 - val_loss: 0.0574 - val_accuracy: 0.9865
# Epoch 4/5
# 657/657 [==============================] - 15s 23ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.0476 - val_accuracy: 0.9894
# Epoch 5/5
# 657/657 [==============================] - 15s 23ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.0524 - val_accuracy: 0.9888

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(h.history['accuracy'], 'o-', label='train accuracy')
plt.plot(h.history['val_accuracy'], 'o-', label = 'validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(h.history['loss'], 'o-', label='train loss')
plt.plot(h.history['val_loss'], 'o-', label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')

plt.show()

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print('\nTest accuracy:', test_acc)
print('\nTest Loss:', test_loss)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0363 - accuracy: 0.9901
#
# Test accuracy: 0.9901000261306763
#
# Test Loss: 0.036288365721702576

# %%
predictions = model.predict(x_test)

# %%
ROWS = 8
COLS = 10

random_indices = random.sample(range(x_test.shape[0]), ROWS*COLS)
sample_images = x_test[random_indices, :]
sample_labels = y_test[random_indices]
predictions = model.predict(sample_images)

i = 0

plt.figure(figsize=(10,8))
for r in range(ROWS):
    for c in range(COLS):
        plt.subplot(ROWS, COLS, i+1)
        plt.imshow(sample_images[i].reshape(28,28), cmap=plt.cm.gray)
        plt.xticks([])
        plt.yticks([])
        prediction = np.argmax(predictions[i]) 
        confidence = predictions[i][prediction]
        if sample_labels[i] == prediction:
            plt.xlabel(f"{prediction} ({confidence: .2f})", color='b')
        else:
            plt.xlabel(f"{prediction} ({confidence: .2f})", color='r')
        plt.ylabel(sample_labels[i], color='g')
        i += 1
        
plt.tight_layout()
plt.show()
